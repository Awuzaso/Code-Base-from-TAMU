# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

'''
asasasasasasasas

asa

d
sds

'''
# Out:
# '\nasasasasasasasas\n\nasa\n\nd\nsds\n\n'

# %%
# d) Visualization and Fourier computation of PVC beats:

N=70;

x_normal=x123[522:584]

x_PVC=x208[1321:1491] #Isolated premature ventricular beat

fft_x_normal=np.fft.rfft(x_normal,N)

fft_x_PVC=np.fft.rfft(x_PVC,N)

f = np.linspace(0,(Fs/2),N/2+1)

plt.figure(10); 
plt.plot(x123[1:2000],'r--',x208[1:2000],'b--') # Comparison over 2000 time samples

# d) Comparison of the frequency spectrum between a normal and a PVC beat.
plt.figure(11);
plt.plot(f,np.abs(fft_x_normal),'r--',f,np.abs(fft_x_PVC),'b--')
# Out:
# [<matplotlib.lines.Line2D at 0x10c8bbb50>,
#  <matplotlib.lines.Line2D at 0x10c8bbc10>]

# %%
x123 = np.loadtxt("/Users/awuzaso/Documents/codingProjects/Tutorial1/123.txt")
x123=x123[:,2]

x208 = np.loadtxt("/Users/awuzaso/Documents/codingProjects/Tutorial1/208.txt")
x208=x208[:,2]

print(x123[0:11])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-cadec8a360d8> in <module>()
# ----> 1 x123 = np.loadtxt("../123.txt")
#       2 x123=x123[:,2]
#       3
#       4 x208 = np.loadtxt("../208.txt")
#       5 x208=x208[:,2]
#
# /usr/local/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     924             fname = str(fname)
#     925         if _is_string_like(fname):
# --> 926             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     927             fencoding = getattr(fh, 'encoding', 'latin1')
#     928             fh = iter(fh)
#
# /usr/local/lib/python2.7/site-packages/numpy/lib/_datasource.pyc in open(path, mode, destpath, encoding, newline)
#     260
#     261     ds = DataSource(destpath)
# --> 262     return ds.open(path, mode, encoding=encoding, newline=newline)
#     263
#     264
#
# /usr/local/lib/python2.7/site-packages/numpy/lib/_datasource.pyc in open(self, path, mode, encoding, newline)
#     616                                       encoding=encoding, newline=newline)
#     617         else:
# --> 618             raise IOError("%s not found." % path)
#     619
#     620
#
# IOError: ../123.txt not found.

# %%
# a) Visualization of normal ECG signal:
L=360
Fs=360

print()

plt.figure(1)
t=np.linspace(0,L,L)/Fs
plt.plot(t,x123[0:L],'b-')
#mpld3.display(fig)
# Out:
# ()

# %%
x123_P=x123[437:521];
x123_QRS=x123[522:584];
x123_T=x123[609:710];

# %%
# b) Fourier computation of ECG components:
N=30 # FFT length

fft_x123_P=np.fft.rfft(x123_P,N)
fft_x123_T=np.fft.rfft(x123_T,N)
fft_x123_QRS=np.fft.rfft(x123_QRS,N)

f = np.linspace(0,(Fs/2),N/2+1)

plt.figure(4);plt.plot(f,np.abs(fft_x123_P),'r--')
plt.figure(5);plt.plot(f,np.abs(fft_x123_T),'b--')
plt.figure(6);plt.plot(f,np.abs(fft_x123_QRS),'g--')

# %%
# c) QRS detection:

def bandpass_filter(x, lowcut, highcut, Fs, filter_order):
    nyquist_freq = 0.5 * Fs
    low = lowcut / nyquist_freq
    high = highcut / nyquist_freq
    b, a = signal.butter(filter_order, [low, high], btype="band")
    y = signal.lfilter(b, a, x)
    return (y,b,a)

def findpeaks(data, spacing, limit):
        print(len(data),spacing)
        x = np.zeros(len(data) + 2 * spacing)
        x[:spacing] = data[0] - 1.e-6
        x[-spacing:] = data[-1] - 1.e-6
        x[spacing:spacing + len(data)] = data
        peak_candidate = np.zeros(len(data))
        peak_candidate[:] = True
        for s in range(spacing):
            start = spacing - s - 1
            h_b = x[start: start + len(data)]  # before
            start = spacing
            h_c = x[start: start + len(data)]  # central
            start = spacing + s + 1
            h_a = x[start: start + len(data)]  # after
            peak_candidate = np.logical_and(peak_candidate, np.logical_and(h_c > h_b, h_c > h_a))
        ind = np.argwhere(peak_candidate)
        ind = ind.reshape(ind.size)
        if limit is not None:
            ind = ind[data[ind] > limit]
        return ind

# segment original signal
L=3000
x=x123[0:L]
t=np.linspace(1,L,L)/Fs

# band-pass filter
def bandPassFilter(in_x,in_lowcut,in_highcut,in_filter_order):
    x = in_x
    (lowcut,highcut,filter_order)=(in_lowcut,in_highcut,in_filter_order)
    (x_bfilt,b,a)=bandpass_filter(x, lowcut, highcut, Fs, filter_order)
    print(L,len(t),len(x))
    plt.figure(1);plt.plot(np.linspace(1,len(x_bfilt),len(x_bfilt))/Fs,x,'b-',t,x_bfilt,'g--')
    return (x_bfilt,b,a)

(lowcut,highcut,filter_order)=(4,15,1)


(x_bfilt,b,a)=bandpass_filter(x, lowcut, highcut, Fs, filter_order)
print(L,len(t),len(x))
plt.figure(7);plt.plot(np.linspace(1,len(x_bfilt),len(x_bfilt))/Fs,x,'b-',t,x_bfilt,'g--')

(bfilt,value1,value1)=bandPassFilter(x,4,15,1)



# differentiate
x_bfilt_diff=np.ediff1d(x_bfilt)
plt.figure(9);plt.plot(np.linspace(1,len(x_bfilt_diff),len(x_bfilt_diff))/Fs,x_bfilt_diff,'r-')


def differentiate(in_x_bfilt):
    x_bfilt_diff = np.ediff1d(in_x_bfilt)
    plt.figure(10);plt.plot(np.linspace(1,len(x_bfilt_diff),len(x_bfilt_diff))/Fs,x_bfilt_diff,'r-')
    return x_bfilt_diff 
    
difVal = differentiate(bfilt)




# square
x_bfilt_diff_sq=x_bfilt_diff**2
plt.figure(10);plt.plot(np.linspace(1,len(x_bfilt_diff_sq),len(x_bfilt_diff_sq))/Fs,x_bfilt_diff_sq,'k--')


def square(in_dif):
    x_bfilt_diff_sq=in_dif**2
    plt.figure(11)
    plt.plot(np.linspace(1,len(x_bfilt_diff_sq),len(x_bfilt_diff_sq))/Fs,x_bfilt_diff_sq,'k--')
    return x_bfilt_diff_sq

sqVal = square(difVal)





# moving average filter
MAfilter_len=15
x_bfilt_diff_sq_smooth = np.convolve(x_bfilt_diff_sq, np.ones(MAfilter_len))
plt.figure(12)
plt.figure(11)
plt.plot(np.linspace(1,len(x_bfilt_diff_sq_smooth),len(x_bfilt_diff_sq_smooth))/Fs,x_bfilt_diff_sq_smooth,'k-')

def movingAvgFilter(in_sqVal,maFilterLen):
    x_bfilt_diff_sq_smooth =  np.convolve(in_sqVal, np.ones(maFilterLen))
    plt.figure(13)
    plt.figure(14)
    plt.plot(np.linspace(1,len(x_bfilt_diff_sq_smooth),len(x_bfilt_diff_sq_smooth))/Fs,x_bfilt_diff_sq_smooth,'k-')
    return x_bfilt_diff_sq_smooth

mvAvFilt = movingAvgFilter(sqVal,15)
    


# find peaks
(findpeaks_limit,findpeaks_spacing)=(0.35,50)
peaks_indices = findpeaks(x_bfilt_diff_sq_smooth,findpeaks_spacing,findpeaks_limit)
#print(peaks_indices/Fs)
print(peaks_indices)
plt.figure(15);
plt.plot(np.linspace(1,len(x),len(x))/Fs,x,'b-',peaks_indices/Fs,x[peaks_indices], 'ro')

'''
def findPeak(in_mvAvFilt,in_lim,in_spacing):
    peaks_indices = findpeaks(in_mvAvFilt,in_spacing,in_lim)
    #print(peaks_indices/Fs)
    plt.figure(16)
    plt.plot(np.linspace(1,len(x),len(x))/Fs,x,'b-',peaks_indices/Fs,x[peaks_indices], 'ro')

(findpeaks_limit,findpeaks_spacing)=(0.35,50)

findPeak(mvAvFilt,findpeaks_limit,findbeaks_spacing)


'''
# Out:
# (3000, 3000, 3000)
# (3000, 3000, 3000)
# (3013, 50)
# [  14  200  304  367  568  681  765  885 1038 1150 1263 1508 1631 1743
#  1935 2058 2153 2358 2473 2606 2832 2952]
# "\ndef findPeak(in_mvAvFilt,in_lim,in_spacing):\n    peaks_indices = findpeaks(in_mvAvFilt,in_spacing,in_lim)\n    #print(peaks_indices/Fs)\n    plt.figure(16)\n    plt.plot(np.linspace(1,len(x),len(x))/Fs,x,'b-',peaks_indices/Fs,x[peaks_indices], 'ro')\n\n(findpeaks_limit,findpeaks_spacing)=(0.35,50)\n\nfindPeak(mvAvFilt,findpeaks_limit,findbeaks_spacing)\n\n\n"
